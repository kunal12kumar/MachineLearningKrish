# %% [markdown]
# # IN this i will anlyze and perform cleaning of  dataset of googleplayStore

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# In this we will first convert each object value to numerical value so, we can use it in airthmetic operation and on anlyzins it by graph

# %%
# for cleaning of dataset let's first work on Installs

# %%
# for that we will first check how many non value it hhas or unique value it has

# %%
# Cleaning of INstalls columns

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
# here we can see that it has + sign at the end first we need to remove it  and also need to  remove Free keywords
# let's first see how many row contains the free

# %%
df[df['Installs']=='Free']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# Let's first copy the dataset and works on that so, there will be no change in main dataset and then after that we will save it 
df_newto=df.copy()

# %%
df_newto
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
# Let's startwoking on df_new

# %%
df_newto[df_newto['Installs']=='Free']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# now delete it

# %%
df_newto=df_newto.drop(df_newto.index[10472])

# %%
df_newto.shape
# Out:
# (10840, 13)

# %%
# now to remove the + sign from it

# %%
df_newto['Installs']=df_newto['Installs'].str.replace('+' ,'')

# %%
df_newto['Installs']
# Out:
# 0            10,000
# 1           500,000
# 2         5,000,000
# 3        50,000,000
# 4           100,000
#             ...
# 10836         5,000
# 10837           100
# 10838         1,000
# 10839         1,000
# 10840    10,000,000
# Name: Installs, Length: 10840, dtype: object

# %%
df_newto['Installs'].isnull().sum()
# Out:
# 0

# %%
# let's draw histograp or kde plot for this 
sns.histplot(df_newto['Installs'] , kde=True )
# Out:
# <Axes: xlabel='Installs', ylabel='Count'>

# %%
df_newto.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size Installs  Type Price Content Rating                     Genres  \
# 0     159  19M   10,000  Free     0       Everyone               Art & Design
# 1     967  14M  500,000  Free     0       Everyone  Art & Design;Pretend Play
#
#        Last Updated Current Ver   Android Ver
# 0   January 7, 2018       1.0.0  4.0.3 and up
# 1  January 15, 2018       2.0.0  4.0.3 and up

# %% [markdown]
# # NOw Work on Size

# %%
# first check for unique value and null value if any

# %%
df_newto['Size'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10840 entries, 0 to 10840
# Series name: Size
# Non-Null Count  Dtype
# --------------  -----
# 10840 non-null  object
# dtypes: object(1)
# memory usage: 169.4+ KB

# %%
df_newto['Size']=df_newto['Size'].str.replace('M' ,'000')
df_newto['Size']=df_newto['Size'].str.replace('k' ,'')

# %%
df_newto['Size']
# Out:
# 0                     19000
# 1                     14000
# 2                    8.7000
# 3                     25000
# 4                    2.8000
#                 ...
# 10836                 53000
# 10837                3.6000
# 10838                9.5000
# 10839    Varies with device
# 10840                 19000
# Name: Size, Length: 10840, dtype: object

# %%
df_newto[df_newto['Size']=='Varies with device'].shape
# Out:
# (1695, 13)

# %%
# Since Varies with device has too many rows so, we cant drop it so, we will replace it with something like mode of this column or nan value
# best way is to first convert it into null values then convert whole size into numecal then after finding  mean or median replace it with the null values

# %%
df_newto['Size']=df_newto['Size'].replace('Varies with device' ,'0')

# %%
df_newto[df_newto['Size']=='Varies with device'].shape
# Out:
# (0, 13)

# %%
df_newto.shape
# Out:
# (10840, 13)

# %%
# now convert all to numerical values
df_newto['Size']=df_newto['Size'].astype('float')

# %%
meanofsize=np.mean(df_newto['Size'])

# %%
meanofsize
# Out:
# 16517.877776752768

# %%
# now fill the 0 with this values 
df_newto['Size']=df_newto['Size'].replace('Nan' , np.nan)

# %%
df_newto['Size'].isnull().sum()
# Out:
# 0

# %%
df_newto['Size']
# Out:
# 0        19000.0
# 1        14000.0
# 2            8.7
# 3        25000.0
# 4            2.8
#           ...
# 10836    53000.0
# 10837        3.6
# 10838        9.5
# 10839        0.0
# 10840    19000.0
# Name: Size, Length: 10840, dtype: float64

# %%
df_newto['Size']=df_newto['Size'].fillna(meanofsize)

# %%
df_newto['Size']
# Out:
# 0        19000.0
# 1        14000.0
# 2            8.7
# 3        25000.0
# 4            2.8
#           ...
# 10836    53000.0
# 10837        3.6
# 10838        9.5
# 10839        0.0
# 10840    19000.0
# Name: Size, Length: 10840, dtype: float64

# %%
# Here we have completed all the data cleanign process we have replace null values and also chang the values in the numerical format

# %%
# now let's do some graph opperaions
sns.histplot(df_newto['Size'],kde=True)
# Out:
# <Axes: xlabel='Size', ylabel='Count'>

# %% [raw]
# # for normal distribution

# %%
sns.kdeplot(x=df_newto['Size'] , shade=True , color="r")
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12680\724931092.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df_newto['Size'] , shade=True , color="r")
# <Axes: xlabel='Size', ylabel='Density'>

# %% [markdown]
# # observation it is left swekwed graph

# %%
df_newto.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews     Size Installs  Type Price Content Rating  \
# 0     159  19000.0   10,000  Free     0       Everyone
# 1     967  14000.0  500,000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %% [markdown]
# # Now we work on Ratings

# %%
df_newto['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , nan, 4.8,
#        4.9, 3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8,
#        2.7, 1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5,
#        1.2])

# %%
df_newto['Rating'].isnull().sum()
# Out:
# 1474

# %%
# since it rating has too much therefore we can't remove this so, we will replace it withe mean of 
meanofratings=df_newto['Rating'].mean()

# %%
meanofratings
# Out:
# 4.191757420456972

# %%
meanofrate=np.mean(df_newto['Rating'])

# %%
meanofrate
# Out:
# 4.191757420456972

# %%
df_newto['Rating']=df_newto['Rating'].fillna(meanofrate)

# %%
df_newto['Rating']
# Out:
# 0        4.100000
# 1        3.900000
# 2        4.700000
# 3        4.500000
# 4        4.300000
#            ...
# 10836    4.500000
# 10837    5.000000
# 10838    4.191757
# 10839    4.500000
# 10840    4.500000
# Name: Rating, Length: 10840, dtype: float64

# %%
df_newto['Rating'].describe()
# Out:
# count    10840.000000
# mean         4.191757
# std          0.478907
# min          1.000000
# 25%          4.100000
# 50%          4.200000
# 75%          4.500000
# max          5.000000
# Name: Rating, dtype: float64

# %%
# now plot graph

# %%
sns.histplot(df_newto['Rating'] , kde=True)
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
sns.kdeplot(x=df_newto['Rating'] , shade=True, color="b")
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12680\2649194054.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df_newto['Rating'] , shade=True, color="b")
# <Axes: xlabel='Rating', ylabel='Density'>

# %% [markdown]
# # observation is right skewed

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %% [markdown]
# # For reviews

# %%
# come on reviews
df_newto['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df_newto['Reviews'].isnull().sum()
# Out:
# 0

# %%
# come on reviews
df_newto['Reviews']=df_newto['Reviews'].astype(float)

# %%
# draw the graph for reviews
sns.histplot(df_newto['Reviews'] , kde=True)
# Out:
# <Axes: xlabel='Reviews', ylabel='Count'>

# %%
sns.kdeplot(x=df_newto['Reviews'] , shade=True , color="y")
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12680\1711104027.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df_newto['Reviews'] , shade=True , color="y")
# <Axes: xlabel='Reviews', ylabel='Density'>

# %%
df_newto.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews     Size    Installs  Type Price Content Rating  \
# 0     159.0  19000.0      10,000  Free     0       Everyone
# 1     967.0  14000.0     500,000  Free     0       Everyone
# 2   87510.0      8.7   5,000,000  Free     0       Everyone
# 3  215644.0  25000.0  50,000,000  Free     0           Teen
# 4     967.0      2.8     100,000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# # From above graph we can say that it is left skewed

# %%
df_newto.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size Installs  Type Price Content Rating  \
# 0    159.0  19000.0   10,000  Free     0       Everyone
# 1    967.0  14000.0  500,000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df_newto['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
plt.figure(figsize=(60 ,10))
sns.histplot(df['Category'])
# Out:
# <Axes: xlabel='Category', ylabel='Count'>

# %%
# now check for any null values
df_newto['Category'].isnull().sum()
# Out:
# 0

# %%
# plot pie chart checking which category has maximum no of apps

# %%
categorycounts=df_newto['Category'].value_counts()

# %%
categorycounts
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# Name: count, dtype: int64

# %%
categorycounts.plot.pie(autopct='%1.1f%%', startangle=90, figsize=(20, 40), cmap='tab10')

# Show the plot
plt.ylabel('')  # Removes the y-label for better visualization
plt.title("Distribution of Categories")  # Adds a title
plt.show()

# %% [markdown]
# # from here we can see that family category has most no. of apps on google app store

# %%
df_newto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  float64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  Categorycounts  0 non-null      float64
# dtypes: float64(4), object(10)
# memory usage: 1.2+ MB

# %%
df_newto.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size Installs  Type Price Content Rating  \
# 0    159.0  19000.0   10,000  Free     0       Everyone
# 1    967.0  14000.0  500,000  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver  \
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
#
#    Categorycounts
# 0             NaN
# 1             NaN

# %%
# Since  numerical values with comma give error if we change it to numerical values so, we replace it with comma then change  the value to  float
df_newto['Installs'] = df_newto['Installs'].str.replace(',', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[103], line 2
#       1 # Since  numerical values with comma give error if we change it to numerical values so, we replace it with comma then change  the value to  float
# ----> 2 df_newto['Installs'] = df_newto['Installs'].str.replace(',', '').astype(float)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\strings\accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\strings\accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df_newto['Installs']
# Out:
# 0           10000.0
# 1          500000.0
# 2         5000000.0
# 3        50000000.0
# 4          100000.0
#             ...
# 10836        5000.0
# 10837         100.0
# 10838        1000.0
# 10839        1000.0
# 10840    10000000.0
# Name: Installs, Length: 10840, dtype: float64

# %%
df_newto.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size  Installs  Type Price Content Rating  \
# 0    159.0  19000.0   10000.0  Free     0       Everyone
# 1    967.0  14000.0  500000.0  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver  \
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
#
#    Categorycounts
# 0             NaN
# 1             NaN

# %%
df_newto['Genres'].unique().size
# Out:
# 119

# %%
Genres_counts=df_newto['Genres'].value_counts()

# %%
Genres_counts
# Out:
# Genres
# Tools                                842
# Entertainment                        623
# Education                            549
# Medical                              463
# Business                             460
#                                     ...
# Parenting;Brain Games                  1
# Travel & Local;Action & Adventure      1
# Lifestyle;Pretend Play                 1
# Tools;Education                        1
# Strategy;Creativity                    1
# Name: count, Length: 119, dtype: int64

# %%
# plot it in the pie chart for the percentage it sares in the category 
Genres_counts.plot.pie(autopct='%f%%' , startangle=90 , figsize=(20, 30))
plt.xlabel('Genres')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # from here we can see that Tools Geners has max no of appps in google play store

# %%
df_newto.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size  Installs  Type Price Content Rating  \
# 0    159.0  19000.0   10000.0  Free     0       Everyone
# 1    967.0  14000.0  500000.0  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver  \
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
#
#    Categorycounts
# 0             NaN
# 1             NaN

# %%
df_newto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  float64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  float64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  Categorycounts  0 non-null      float64
# dtypes: float64(5), object(9)
# memory usage: 1.2+ MB

# %% [markdown]
# # The features nedd to changes to numerical are:-
# 1. Price
# 2.Last Updated
# 3. Current version
# 4. current rating
# 5.DAte
# 6.android ver

# %%
df_newto['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
# since this contain dollar sign so, we cant change it into the interger or float so, first we remvoe dollar sign 
df_newto['Price']= df_newto['Price'].str.replace('$' , '')

# %%
df_newto['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df_newto['Price'].value_counts()
# Out:
# Price
# 0        10040
# 0.99       148
# 2.99       129
# 1.99        73
# 4.99        72
#          ...
# 19.90        1
# 1.75         1
# 14.00        1
# 4.85         1
# 1.04         1
# Name: count, Length: 92, dtype: int64

# %%
# now change the object  value to count
df_newto['Price']=df_newto['Price'].astype(float)

# %%
df_newto['Price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10840 entries, 0 to 10840
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 10840 non-null  float64
# dtypes: float64(1)
# memory usage: 169.4 KB

# %%
Price_counts=df_newto['Price'].value_counts()

# %%
Price_counts.plot.pie(autopct="%f%%" , startangle=90 , figsize=(20 , 30))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # most app has  0 price

# %% [markdown]
# # now we have to deal with lastupdated

# %%
df_newto['Last Updated']
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 10840, dtype: object

# %%
# for date  we will distingguish it in month , day , year 
df_newto['Day']=df_newto['Last Updated']
